# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn as sl
import seaborn as sns

# %%
data=pd.read_csv("d5.csv")

# %%
data
# Out:
#         GasSR  Humidity  Pressure  Temperature  PM1  PM10  PM2_5  IAQ  \
# 0      299.47     47.74   1004.91        29.57   51    75     65   55
# 1      300.03     47.47   1004.85        29.71   54    78     68   60
# 2      297.70     47.10   1004.83        29.81   57    78     70   60
# 3      295.00     47.89   1004.83        29.96   61    82     76   55
# 4      293.43     47.47   1004.83        30.07   58    79     73   60
# ...       ...       ...       ...          ...  ...   ...    ...  ...
# 42393  141.17     61.39   1008.92        29.84   24    39     35  160
# 42394  139.60     61.51   1008.92        29.83   22    35     32  160
# 42395  139.61     61.37   1008.92        29.83   23    47     34  160
# 42396  139.88     61.35   1008.90        29.83   22    48     35  160
# 42397  140.00     61.31   1008.90        29.82   22    41     34  160
#
#                 AQI
# 0      SATISFACTORY
# 1      SATISFACTORY
# 2      SATISFACTORY
# 3      SATISFACTORY
# ...

# %%
data.head()
# Out:
#     GasSR  Humidity  Pressure  Temperature  PM1  PM10  PM2_5  IAQ  \
# 0  299.47     47.74   1004.91        29.57   51    75     65   55
# 1  300.03     47.47   1004.85        29.71   54    78     68   60
# 2  297.70     47.10   1004.83        29.81   57    78     70   60
# 3  295.00     47.89   1004.83        29.96   61    82     76   55
# 4  293.43     47.47   1004.83        30.07   58    79     73   60
#
#             AQI
# 0  SATISFACTORY
# 1  SATISFACTORY
# 2  SATISFACTORY
# 3  SATISFACTORY
# 4  SATISFACTORY

# %%
data.tail()
# Out:
#         GasSR  Humidity  Pressure  Temperature  PM1  PM10  PM2_5  IAQ  \
# 42393  141.17     61.39   1008.92        29.84   24    39     35  160
# 42394  139.60     61.51   1008.92        29.83   22    35     32  160
# 42395  139.61     61.37   1008.92        29.83   23    47     34  160
# 42396  139.88     61.35   1008.90        29.83   22    48     35  160
# 42397  140.00     61.31   1008.90        29.82   22    41     34  160
#
#             AQI
# 42393  MODERATE
# 42394  MODERATE
# 42395  MODERATE
# 42396  MODERATE
# 42397  MODERATE

# %%
data.shape
# Out:
# (42398, 9)

# %%
data.size
# Out:
# 381582

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42398 entries, 0 to 42397
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   GasSR        42398 non-null  float64
#  1   Humidity     42398 non-null  float64
#  2   Pressure     42398 non-null  float64
#  3   Temperature  42398 non-null  float64
#  4   PM1          42398 non-null  int64
#  5   PM10         42398 non-null  int64
#  6   PM2_5        42398 non-null  int64
#  7   IAQ          42398 non-null  int64
#  8   AQI          42398 non-null  object
# dtypes: float64(4), int64(4), object(1)
# memory usage: 2.9+ MB

# %%
data.describe()
# Out:
#               GasSR      Humidity      Pressure   Temperature           PM1  \
# count  42398.000000  42398.000000  42398.000000  42398.000000  42398.000000
# mean     198.329093     54.501049   1004.852239     29.465901     48.602623
# std       43.596490      5.427747      2.025762      1.900955     55.133784
# min       41.420000     34.240000    999.740000     24.100000      0.000000
# 25%      170.650000     50.890000   1003.460000     28.020000     19.000000
# 50%      188.670000     55.660000   1004.810000     29.940000     29.000000
# 75%      216.927500     58.670000   1006.280000     30.840000     55.000000
# max      531.530000     68.430000   1010.530000     33.350000    476.000000
#
#                PM10         PM2_5           IAQ
# count  42398.000000  42398.000000  42398.000000
# mean      76.059130     65.321029     98.503231
# std      123.033599     81.675318     36.642875
# min        3.000000      0.000000      0.000000
# ...

# %%
data.columns
# Out:
# Index(['GasSR', 'Humidity', 'Pressure', 'Temperature', 'PM1', 'PM10', 'PM2_5',
#        'IAQ', 'AQI'],
#       dtype='object')

# %%
data.isnull().sum()
# Out:
# GasSR          0
# Humidity       0
# Pressure       0
# Temperature    0
# PM1            0
# PM10           0
# PM2_5          0
# IAQ            0
# AQI            0
# dtype: int64

# %%
data.hist(bins=20,figsize=(20,15))
# Out:
# array([[<AxesSubplot:title={'center':'GasSR'}>,
#         <AxesSubplot:title={'center':'Humidity'}>,
#         <AxesSubplot:title={'center':'Pressure'}>],
#        [<AxesSubplot:title={'center':'Temperature'}>,
#         <AxesSubplot:title={'center':'PM1'}>,
#         <AxesSubplot:title={'center':'PM10'}>],
#        [<AxesSubplot:title={'center':'PM2_5'}>,
#         <AxesSubplot:title={'center':'IAQ'}>, <AxesSubplot:>]],
#       dtype=object)

# %%
#scatter plot

# %%
colors=['red','blue','green']
AQI=['Poor','Very Poor','Severe']

# %%
for i in range(2):
 x=data[data['AQI'] == AQI[i]]
 plt.scatter(x["PM10"],x["PM2_5"], c=colors[i], label=AQI[i])
plt.xlabel("PM10")
plt.ylabel("PM2_5")
plt.legend()

# %%
colors=['aqua','pink','purple']
AQI=['Good','Satisfactory','Moderate']

# %%
for i in range(2):
 x=data[data['AQI'] == AQI[i]]
 plt.scatter(x["PM2_5"],x["PM10"], c=colors[i], label=AQI[i])
plt.xlabel("PM2_5")
plt.ylabel("PM10")
plt.legend()

# %%
import seaborn as sns
sns.pairplot(data, hue='AQI')

# %% [markdown]
# ### bar plot

# %%
data.plot(kind='bar',x='AQI',y='PM10',color='pink');
plt.title('AQI and PM10')
plt.xlabel("AQI")
plt.ylabel("PM10")
# Out:
# Text(0, 0.5, 'PM10')

# %%
x=data['AQI']
y=data['PM2_5']
plt.bar(x,y,color='green')
plt.title('AQI and PM2_5')
plt.xlabel("AQI")
plt.ylabel("PM2_5")
# Out:
# Text(0, 0.5, 'PM2_5')

# %%
data.plot(kind='box',y=['GasSR','Humidity','Pressure','Temperature','PM1','PM10','PM2_5','IAQ']);

# %%
#plt.plot(data.,label='PM2_5')
plt.plot(data.AQI,label='PM10',marker='.')
plt.plot(data.Temperature,label='IAQ',marker='.')
#plt.xlabel('')
#plt.ylabel('count')
plt.legend()

# %%
change_satis = {"AQI": { "satisfactory": "Satisfactory"}}
data=data.replace(change_satis)

# %%
data.groupby(['AQI']).sum().plot(kind='pie', y='IAQ',autopct='%1.0f%%')
# Out:
# <AxesSubplot:ylabel='IAQ'>

# %%
corr=data.corr()
plt.subplots(figsize=(9,6))
sns.heatmap(corr,annot=True)
# Out:
# <AxesSubplot:>

# %%
data2 = data.copy()

# %%
#### replace null values with mean

# %%
data2 = data2.fillna(data2.mean())
# Out:
# C:\Users\harha\AppData\Local\Temp\ipykernel_16372\997279670.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   data2 = data2.fillna(data2.mean())

# %%
data2
# Out:
#         GasSR  Humidity  Pressure  Temperature  PM1  PM10  PM2_5  IAQ  \
# 0      299.47     47.74   1004.91        29.57   51    75     65   55
# 1      300.03     47.47   1004.85        29.71   54    78     68   60
# 2      297.70     47.10   1004.83        29.81   57    78     70   60
# 3      295.00     47.89   1004.83        29.96   61    82     76   55
# 4      293.43     47.47   1004.83        30.07   58    79     73   60
# ...       ...       ...       ...          ...  ...   ...    ...  ...
# 42393  141.17     61.39   1008.92        29.84   24    39     35  160
# 42394  139.60     61.51   1008.92        29.83   22    35     32  160
# 42395  139.61     61.37   1008.92        29.83   23    47     34  160
# 42396  139.88     61.35   1008.90        29.83   22    48     35  160
# 42397  140.00     61.31   1008.90        29.82   22    41     34  160
#
#                 AQI
# 0      SATISFACTORY
# 1      SATISFACTORY
# 2      SATISFACTORY
# 3      SATISFACTORY
# ...

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42398 entries, 0 to 42397
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   GasSR        42398 non-null  float64
#  1   Humidity     42398 non-null  float64
#  2   Pressure     42398 non-null  float64
#  3   Temperature  42398 non-null  float64
#  4   PM1          42398 non-null  int64
#  5   PM10         42398 non-null  int64
#  6   PM2_5        42398 non-null  int64
#  7   IAQ          42398 non-null  int64
#  8   AQI          42398 non-null  object
# dtypes: float64(4), int64(4), object(1)
# memory usage: 2.9+ MB

# %%
data2.columns
# Out:
# Index(['GasSR', 'Humidity', 'Pressure', 'Temperature', 'PM1', 'PM10', 'PM2_5',
#        'IAQ', 'AQI'],
#       dtype='object')

# %%
dist=(data2['AQI'])
distset=set(dist)
dd=list(distset)
dictofwords={dd[i] : i for i in range(0, len(dd))}
data2['AQI']=data2['AQI'].map(dictofwords)

# %%
data2
# Out:
#         GasSR  Humidity  Pressure  Temperature  PM1  PM10  PM2_5  IAQ  AQI
# 0      299.47     47.74   1004.91        29.57   51    75     65   55    0
# 1      300.03     47.47   1004.85        29.71   54    78     68   60    0
# 2      297.70     47.10   1004.83        29.81   57    78     70   60    0
# 3      295.00     47.89   1004.83        29.96   61    82     76   55    0
# 4      293.43     47.47   1004.83        30.07   58    79     73   60    0
# ...       ...       ...       ...          ...  ...   ...    ...  ...  ...
# 42393  141.17     61.39   1008.92        29.84   24    39     35  160    1
# 42394  139.60     61.51   1008.92        29.83   22    35     32  160    1
# 42395  139.61     61.37   1008.92        29.83   23    47     34  160    1
# 42396  139.88     61.35   1008.90        29.83   22    48     35  160    1
# 42397  140.00     61.31   1008.90        29.82   22    41     34  160    1
#
# [42398 rows x 9 columns]

# %%
data2.tail()
# Out:
#         GasSR  Humidity  Pressure  Temperature  PM1  PM10  PM2_5  IAQ  AQI
# 42393  141.17     61.39   1008.92        29.84   24    39     35  160    1
# 42394  139.60     61.51   1008.92        29.83   22    35     32  160    1
# 42395  139.61     61.37   1008.92        29.83   23    47     34  160    1
# 42396  139.88     61.35   1008.90        29.83   22    48     35  160    1
# 42397  140.00     61.31   1008.90        29.82   22    41     34  160    1

# %%
data2.isnull().sum()
# Out:
# GasSR          0
# Humidity       0
# Pressure       0
# Temperature    0
# PM1            0
# PM10           0
# PM2_5          0
# IAQ            0
# AQI            0
# dtype: int64

# %%
IAQ_bins = [0,50,100,200,300,400,500]
IAQ_labels = ["Good", "Satisfactory", "Moderate", "poor","Very poor","Severe"]
data2['IAQc'] = pd.cut(data2['IAQ'], IAQ_bins, labels=IAQ_labels, 
 right=True, include_lowest=True)
data2
# Out:
#         GasSR  Humidity  Pressure  Temperature  PM1  PM10  PM2_5  IAQ  AQI  \
# 0      299.47     47.74   1004.91        29.57   51    75     65   55    0
# 1      300.03     47.47   1004.85        29.71   54    78     68   60    0
# 2      297.70     47.10   1004.83        29.81   57    78     70   60    0
# 3      295.00     47.89   1004.83        29.96   61    82     76   55    0
# 4      293.43     47.47   1004.83        30.07   58    79     73   60    0
# ...       ...       ...       ...          ...  ...   ...    ...  ...  ...
# 42393  141.17     61.39   1008.92        29.84   24    39     35  160    1
# 42394  139.60     61.51   1008.92        29.83   22    35     32  160    1
# 42395  139.61     61.37   1008.92        29.83   23    47     34  160    1
# 42396  139.88     61.35   1008.90        29.83   22    48     35  160    1
# 42397  140.00     61.31   1008.90        29.82   22    41     34  160    1
#
#                IAQc
# 0      Satisfactory
# 1      Satisfactory
# ...

# %%
data2=data2.drop('IAQ',1)
data2=data2.drop('AQI',1)
# Out:
# C:\Users\harha\AppData\Local\Temp\ipykernel_16372\97047759.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   data2=data2.drop('IAQ',1)
# C:\Users\harha\AppData\Local\Temp\ipykernel_16372\97047759.py:2: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   data2=data2.drop('AQI',1)

# %%
data2.columns
# Out:
# Index(['GasSR', 'Humidity', 'Pressure', 'Temperature', 'PM1', 'PM10', 'PM2_5',
#        'IAQc'],
#       dtype='object')

# %%
features=data2.drop(['IAQc'], axis=1)
labels=data2['IAQc']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(features,labels,test_size=0.2,random_state=2)

# %%
X_train
# Out:
#         GasSR  Humidity  Pressure  Temperature  PM1  PM10  PM2_5
# 2431   172.29     59.99   1007.03        31.32   37    66     51
# 35036  190.47     56.22   1003.87        31.15    6     8      8
# 14801  175.90     56.91   1006.09        30.78   16    35     22
# 29800  233.69     48.11   1001.57        27.69   31    50     42
# 2669   206.52     55.30   1008.27        28.01   25    44     34
# ...       ...       ...       ...          ...  ...   ...    ...
# 31019  160.53     52.19   1003.40        26.74   92   133    118
# 30280  167.47     57.83   1004.40        29.81   68    87     85
# 6637   178.07     55.18   1004.47        32.53   21    31     28
# 35343  232.14     42.58   1005.48        28.59  201   252    245
# 23720  168.57     65.50   1006.21        27.73   28    52     40
#
# [33918 rows x 7 columns]

# %%
X_test
# Out:
#         GasSR  Humidity  Pressure  Temperature  PM1  PM10  PM2_5
# 37102  186.49     56.69   1001.90        30.39   20    30     26
# 8894   192.79     45.07   1001.88        28.19   44    71     56
# 631    221.46     55.11   1009.21        30.65   54    78     69
# 30613  167.66     59.89   1001.51        29.28    7    13     10
# 36908  234.81     51.17   1004.06        26.20   38    63     51
# ...       ...       ...       ...          ...  ...   ...    ...
# 16446  167.46     61.34   1007.07        30.64   13    26     16
# 34739  204.24     55.60   1004.57        30.97   15    20     19
# 42052  171.34     59.27   1007.36        30.09   15    26     24
# 6871   148.63     60.58   1006.21        31.45   26    47     37
# 40871  159.30     62.74   1007.60        30.43   41    66     53
#
# [8480 rows x 7 columns]

# %%
y_train
# Out:
# 2431         Moderate
# 35036    Satisfactory
# 14801        Moderate
# 29800    Satisfactory
# 2669     Satisfactory
#              ...
# 31019        Moderate
# 30280        Moderate
# 6637         Moderate
# 35343        Moderate
# 23720        Moderate
# Name: IAQc, Length: 33918, dtype: category
# Categories (6, object): ['Good' < 'Satisfactory' < 'Moderate' < 'poor' < 'Very poor' < 'Severe']

# %%
y_test
# Out:
# 37102    Satisfactory
# 8894         Moderate
# 631      Satisfactory
# 30613        Moderate
# 36908            Good
#              ...
# 16446        Moderate
# 34739    Satisfactory
# 42052        Moderate
# 6871         Moderate
# 40871        Moderate
# Name: IAQc, Length: 8480, dtype: category
# Categories (6, object): ['Good' < 'Satisfactory' < 'Moderate' < 'poor' < 'Very poor' < 'Severe']

# %% [markdown]
# ### SVM

# %%
from sklearn import svm
from sklearn.metrics import accuracy_score

# %%
svm = svm.SVC()

# %%
svm.fit(X_train,y_train)
# Out:
# SVC()

# %%
y_pred1 = svm.predict(X_test)

# %%
acc=accuracy_score(y_test,y_pred1)
per1=acc*100
print(per1)
# Out:
# 80.34198113207547

# %%
from sklearn.metrics import confusion_matrix, classification_report
print(classification_report(y_test,y_pred1))
# Out:
#               precision    recall  f1-score   support
#
#         Good       0.00      0.00      0.00       938
#     Moderate       0.90      0.91      0.90      3684
# Satisfactory       0.73      0.91      0.81      3802
#         poor       0.00      0.00      0.00        56
#
#     accuracy                           0.80      8480
#    macro avg       0.41      0.46      0.43      8480
# weighted avg       0.72      0.80      0.76      8480
# C:\Users\harha\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %%
from sklearn.preprocessing import label_binarize
#binarize the y_values
y_test_binarized=label_binarize(y_test,classes=np.unique(y_test))
classes=np.unique(y_test)
#roc curve for classes
fpr={}
tpr={}
thresh={}
roc_auc=dict()
#n_class=classes.shape[0]
for i in range(4):
 fpr[i],tpr[i],thresh[i]=roc_curve(y_test_binarized[:,i],pred_prob[:,i])
 roc_auc[i]=auc(fpr[i],tpr[i])
 
 #plotting
 plt.plot(fpr[i],tpr[i],linestyle='--',
 label='%s vs Rest (AUC=%0.2f)'%(classes[i],roc_auc[i]))
plt.plot([0,1],[0,1],'b--')
plt.xlim([0,1])
plt.ylim([0,1.05])
plt.title('ROC curve of SVM')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# ### KNN ALGORITHM

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn = KNeighborsClassifier()

# %%
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred2 = knn.predict(X_test)

# %%
acc=accuracy_score(y_test,y_pred2)
per2=acc*100
print(per2)
# Out:
# 93.01886792452831

# %%
from sklearn.metrics import confusion_matrix, classification_report
print(classification_report(y_test,y_pred2))
# Out:
#               precision    recall  f1-score   support
#
#         Good       0.88      0.85      0.87       938
#     Moderate       0.96      0.95      0.95      3684
# Satisfactory       0.92      0.94      0.93      3802
#         poor       0.70      0.54      0.61        56
#
#     accuracy                           0.93      8480
#    macro avg       0.86      0.82      0.84      8480
# weighted avg       0.93      0.93      0.93      8480

# %%
from sklearn.multiclass import OneVsRestClassifier
#from sklearn.svm import SVC 
from sklearn import svm
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import roc_curve,auc

# %%
y_predroc = knn.predict(X_test)
pred_prob = knn.predict_proba(X_test)
pred_prob.shape
# Out:
# (8480, 4)

# %%
from sklearn.preprocessing import label_binarize
#binarize the y_values
y_test_binarized=label_binarize(y_test,classes=np.unique(y_test))
classes=np.unique(y_test)
#roc curve for classes
fpr={}
tpr={}
thresh={}
roc_auc=dict()
#n_class=classes.shape[0]
for i in range(4):
 fpr[i],tpr[i],thresh[i]=roc_curve(y_test_binarized[:,i],pred_prob[:,i])
 roc_auc[i]=auc(fpr[i],tpr[i])
 
 #plotting
 plt.plot(fpr[i],tpr[i],linestyle='--',
 label='%s vs Rest (AUC=%0.2f)'%(classes[i],roc_auc[i]))
plt.plot([0,1],[0,1],'b--')
plt.xlim([0,1])
plt.ylim([0,1.05])
plt.title('ROC curve of KNN')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# ### Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

# %%
log = LogisticRegression()
log.fit(X_train,y_train)
# Out:
# C:\Users\harha\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
y_pred3 = log.predict(X_test)

# %%
acc=accuracy_score(y_test,y_pred3)
per3=acc*100
print(per3)
# Out:
# 80.2004716981132

# %%
from sklearn.metrics import confusion_matrix, classification_report
print(classification_report(y_test,y_pred3))
# Out:
#               precision    recall  f1-score   support
#
#         Good       0.53      0.16      0.24       938
#     Moderate       0.88      0.92      0.90      3684
# Satisfactory       0.76      0.85      0.80      3802
#         poor       0.47      0.41      0.44        56
#
#     accuracy                           0.80      8480
#    macro avg       0.66      0.59      0.59      8480
# weighted avg       0.78      0.80      0.78      8480

# %%
from sklearn.multiclass import OneVsRestClassifier
#from sklearn.svm import SVC 
from sklearn import svm
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_curve,auc

# %%
y_predroc = log.predict(X_test)
pred_prob = log.predict_proba(X_test)
pred_prob.shape
# Out:
# (8480, 4)

# %%
from sklearn.preprocessing import label_binarize
#binarize the y_values
y_test_binarized=label_binarize(y_test,classes=np.unique(y_test))
classes=np.unique(y_test)
#roc curve for classes
fpr={}
tpr={}
thresh={}
roc_auc=dict()
#n_class=classes.shape[0]
for i in range(4):
 fpr[i],tpr[i],thresh[i]=roc_curve(y_test_binarized[:,i],pred_prob[:,i])
 roc_auc[i]=auc(fpr[i],tpr[i])
 
 #plotting
 plt.plot(fpr[i],tpr[i],linestyle='--',
 label='%s vs Rest (AUC=%0.2f)'%(classes[i],roc_auc[i]))
plt.plot([0,1],[0,1],'b--')
plt.xlim([0,1])
plt.ylim([0,1.05])
plt.title('ROC curve of Logistic Regression')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# ### Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dt=DecisionTreeClassifier()

# %%
dt.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred4 = dt.predict(X_test)

# %%
acc=accuracy_score(y_test, y_pred4)
per4=acc*100
print(per4)
# Out:
# 98.8561320754717

# %%
from sklearn.metrics import confusion_matrix, classification_report
print(classification_report(y_test,y_pred4))
# Out:
#               precision    recall  f1-score   support
#
#         Good       0.99      0.99      0.99       938
#     Moderate       0.99      0.99      0.99      3684
# Satisfactory       0.99      0.99      0.99      3802
#         poor       0.83      0.88      0.85        56
#
#     accuracy                           0.99      8480
#    macro avg       0.95      0.96      0.95      8480
# weighted avg       0.99      0.99      0.99      8480

# %%
cm=confusion_matrix(y_test, y_pred4)
cm
# Out:
# array([[ 926,    0,   12,    0],
#        [   0, 3644,   30,   10],
#        [  12,   26, 3764,    0],
#        [   0,    7,    0,   49]], dtype=int64)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
#sns.heatmap(cm,cmap='Greens',annot=True,
 #cbar_kws={'orientation':'vertical','label':'color bar'},
 #xticklabels=[0,1],yticklabels=[0,1] ) 
sns.heatmap(cm,annot=True, cmap='Blues', fmt='d',cbar=False, annot_kws={'size':12})
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %% [markdown]
# # AUC PLOT

# %%
from sklearn.multiclass import OneVsRestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import roc_curve,auc

# %%
#DT=OneVsRestClassifier(DecisionTreeClassifier)
#DT.fit(X_train,y_train)
y_predroc=dt.predict(X_test)
pred_prob=dt.predict_proba(X_test)

# %%
pred_prob.shape
# Out:
# (8480, 4)

# %%
from sklearn.preprocessing import label_binarize
#binarize the y_values
y_test_binarized=label_binarize(y_test,classes=np.unique(y_test))
classes=np.unique(y_test)
#roc curve for classes
fpr={}
tpr={}
thresh={}
roc_auc=dict()
#n_class=classes.shape[0]
for i in range(4):
 fpr[i],tpr[i],thresh[i]=roc_curve(y_test_binarized[:,i],pred_prob[:,i])
 roc_auc[i]=auc(fpr[i],tpr[i])
 
 #plotting
plt.plot(fpr[i],tpr[i],linestyle='--',
label='%s vs Rest (AUC=%0.2f)'%(classes[i],roc_auc[i]))
plt.plot([0,1],[0,1],'b--')
plt.xlim([0,1])
plt.ylim([0,1.05])
plt.title('ROC curve of Decision Tree Classifier')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# ### Comparison

# %%
final_data = pd.DataFrame({'MODELS':['SVM','KNN','LR','DT'], 
 'ACCURACY':[per1, per2, per3, per4]})

# %%
final_data
# Out:
#   MODELS   ACCURACY
# 0    SVM  80.341981
# 1    KNN  93.018868
# 2     LR  80.200472
# 3     DT  98.856132

# %%
import seaborn as sns

# %%
sns.barplot(final_data['MODELS'], final_data['ACCURACY'])
# Out:
# C:\Users\harha\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='MODELS', ylabel='ACCURACY'>

# %% [markdown]
# ### Prediction on New Data

# %%
dt.predict([[130, 64.31, 1009.46, 30.39, 22, 46, 32]])
# Out:
# C:\Users\harha\anaconda3\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array(['Moderate'], dtype=object)
